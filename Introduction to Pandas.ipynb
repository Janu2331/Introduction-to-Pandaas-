# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  23.00   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
#Get information
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
dataset.columns
# Out:
# Index(['CustomerID', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9',
#        'A10', 'A11', 'A12', 'A13', 'A14', 'Class'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#          CustomerID          A1          A2          A3          A4  \
# count  6.900000e+02  690.000000  690.000000  690.000000  690.000000
# mean   1.569047e+07    0.678261   31.568203    4.758725    1.766667
# std    7.150647e+04    0.467482   11.853273    4.978163    0.430063
# min    1.556571e+07    0.000000   13.750000    0.000000    1.000000
# 25%    1.563169e+07    0.000000   22.670000    1.000000    2.000000
# 50%    1.569016e+07    1.000000   28.625000    2.750000    2.000000
# 75%    1.575190e+07    1.000000   37.707500    7.207500    2.000000
# max    1.581544e+07    1.000000   80.250000   28.000000    3.000000
#
#                A5          A6          A7          A8          A9        A10  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.00000
# mean     7.372464    4.692754    2.223406    0.523188    0.427536    2.40000
# std      3.683265    1.992316    3.346513    0.499824    0.495080    4.86294
# ...

# %%
#loc-iloc
#dframr.loc[rows,columns]
dataset.loc[[0,1,5],['A11','A2','A1']]
# Out:
#    A11     A2  A1
# 0    1  22.08   1
# 1    0  22.67   0
# 5    0  15.83   0

# %%
dataset.iloc[[0,1,5],[11,2,1]]
# Out:
#    A11     A2  A1
# 0    1  22.08   1
# 1    0  22.67   0
# 5    0  15.83   0

# %%
dataset.loc[1,'A2']
# Out:
# 22.67

# %%
dataset.loc[1,'A2']=23

# %%
dataset.loc[1,'A2']
# Out:
# 23.0

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
 age.append(random.randint(0,100))
 height.append(random.randint(0,100))
 weight.append(random.randint(0,100))
 speed.append(random.randint(0,100))
 idata = {'Age':age,'Height':height,'Weight':weight,'speed':speed}

# %%
idata
# Out:
# {'Age': [24,
#   6,
#   37,
#   27,
#   37,
#   43,
#   30,
#   80,
#   86,
#   41,
#   41,
#   38,
#   2,
#   52,
#   82,
#   56,
#   22,
#   56,
#   71,
#   44,
#   20,
#   8,
#   55,
#   97,
#   19,
#   15,
#   76,
#   28,
#   68,
#   73,
#   43,
#   91,
#   1,
#   23,
#   42,
#   71,
#   72,
#   66,
#   43,
#   15,
#   14,
#   91,
#   30,
#   80,
#   12,
#   86,
#   37,
#   29,
#   13,
#   88,
#   51,
#   15,
#   3,
#   28,
#   60,
#   28,
#   9,
#   81,
#   22,
#   66,
#   85,
#   0,
#   71,
#   33,
#   58,
#   52,
#   99,
#   30,
#   52,
#   45,
#   97,
#   39,
#   77,
#   19,
#   25,
#   44,
#   54,
#   23,
#   94,
#   64,
#   59,
#   32,
#   67,
#   62,
#   98,
#   50,
#   98,
#   20,
#   100,
#   60,
#   81,
#   6,
#   44,
#   84,
#   36,
#   74,
#   5,
#   38,
#   29,
#   25],
#  'Height': [25,
#   63,
#   81,
#   40,
#   38,
#   29,
#   56,
#   28,
#   86,
#   81,
#   85,
#   83,
#   81,
#   87,
#   77,
#   10,
#   49,
#   33,
#   54,
#   41,
#   83,
#   76,
#   92,
# ...

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  speed
# 0    24      25      34     17
# 1     6      63      66     53
# 2    37      81      69     42
# 3    27      40      11     51
# 4    37      38      19     83
# ..  ...     ...     ...    ...
# 95   74      21      57     50
# 96    5      30       6      6
# 97   38      71      79     47
# 98   29      30      62      8
# 99   25      56     100     49
#
# [100 rows x 4 columns]

# %%
df1.tail(10)
# Out:
#     Age  Height  Weight  speed
# 90   81       5      99     78
# 91    6      32      90     80
# 92   44       7      58     55
# 93   84       4      14     21
# 94   36      79      55     48
# 95   74      21      57     50
# 96    5      30       6      6
# 97   38      71      79     47
# 98   29      30      62      8
# 99   25      56     100     49

# %%
df1.describe()
# Out:
#               Age     Height      Weight       speed
# count  100.000000  100.00000  100.000000  100.000000
# mean    47.730000   49.26000   52.030000   51.910000
# std     28.003194   28.74957   30.145256   28.749737
# min      0.000000    2.00000    2.000000    6.000000
# 25%     25.000000   24.75000   23.000000   31.750000
# 50%     43.500000   48.00000   56.000000   50.000000
# 75%     71.000000   77.25000   78.250000   79.000000
# max    100.000000  100.00000  100.000000  100.000000

# %%
df1['Age']
# Out:
# 0     24
# 1      6
# 2     37
# 3     27
# 4     37
#       ..
# 95    74
# 96     5
# 97    38
# 98    29
# 99    25
# Name: Age, Length: 100, dtype: int64

# %%
df1.loc[[0,3],['Age','Weight']]
# Out:
#    Age  Weight
# 0   24      34
# 3   27      11

# %%
df2 = df1[['Age','Weight']]

# %%
df2
# Out:
#     Age  Weight
# 0    24      34
# 1     6      66
# 2    37      69
# 3    27      11
# 4    37      19
# ..  ...     ...
# 95   74      57
# 96    5       6
# 97   38      79
# 98   29      62
# 99   25     100
#
# [100 rows x 2 columns]

# %%
df2.sort_index(ascending=False)
# Out:
#     Age  Weight
# 99   25     100
# 98   29      62
# 97   38      79
# 96    5       6
# 95   74      57
# ..  ...     ...
# 4    37      19
# 3    27      11
# 2    37      69
# 1     6      66
# 0    24      34
#
# [100 rows x 2 columns]

# %%
#slicing method
df1[0::2]
# Out:
#     Age  Height  Weight  speed
# 0    24      25      34     17
# 2    37      81      69     42
# 4    37      38      19     83
# 6    30      56       8     72
# 8    86      86       4     94
# 10   41      85      80     21
# 12    2      81      19     81
# 14   82      77      79     46
# 16   22      49      23     13
# 18   71      54      97     56
# 20   20      83      12     79
# 22   55      92      53     21
# 24   19      10      26     56
# 26   76      67      55     91
# 28   68      83      99     63
# 30   43      79      45    100
# 32    1      47      91     73
# 34   42      13      40     84
# 36   72      67      62     28
# 38   43      24      27      9
# 40   14      30      97     98
# 42   30       2       2     52
# 44   12      16      28     59
# 46   37      11      57     56
# 48   13      71      45     40
# 50   51      95      65     83
# 52    3      58       8     54
# 54   60      78      72     54
# 56    9      19      88     11
# ...

# %%
df1[0::2].describe()
# Out:
#               Age     Height     Weight       speed
# count   50.000000  50.000000  50.000000   50.000000
# mean    49.020000  49.040000  51.060000   57.480000
# std     29.784594  29.291609  31.273912   28.192661
# min      1.000000   2.000000   2.000000    6.000000
# 25%     24.250000  24.250000  23.250000   38.500000
# 50%     43.500000  51.000000  55.000000   56.000000
# 75%     71.750000  78.750000  77.500000   82.500000
# max    100.000000  95.000000  99.000000  100.000000

# %%
#filter-with conditional operators
filter1 = df1['Weight'] > 50

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  speed
# 1     6      63      66     53
# 2    37      81      69     42
# 9    41      81      51      7
# 10   41      85      80     21
# 13   52      87      64     65
# 14   82      77      79     46
# 15   56      10      71     49
# 18   71      54      97     56
# 21    8      76      92     10
# 22   55      92      53     21
# 26   76      67      55     91
# 27   28      59      67     41
# 28   68      83      99     63
# 29   73      11      83     72
# 31   91      45      95     32
# 32    1      47      91     73
# 33   23      93      82     20
# 36   72      67      62     28
# 39   15      45      78     39
# 40   14      30      97     98
# 41   91      93      51     31
# 46   37      11      57     56
# 49   88      22      79     46
# 50   51      95      65     83
# 51   15      80      73     56
# 53   28       6      62     19
# 54   60      78      72     54
# 56    9      19      88     11
# 57   81      57      78     13
# ...

# %%
filter2 = df1['Age'] > 40

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  Weight  speed
# 9    41      81      51      7
# 10   41      85      80     21
# 13   52      87      64     65
# 14   82      77      79     46
# 15   56      10      71     49
# 18   71      54      97     56
# 22   55      92      53     21
# 26   76      67      55     91
# 28   68      83      99     63
# 29   73      11      83     72
# 31   91      45      95     32
# 36   72      67      62     28
# 41   91      93      51     31
# 49   88      22      79     46
# 50   51      95      65     83
# 54   60      78      72     54
# 57   81      57      78     13
# 60   85      79      91     38
# 64   58      24      62     21
# 66   99       8      73     46
# 69   45      29      70     79
# 72   77      84      55     83
# 75   44      49      82     89
# 76   54      27      58     98
# 78   94      60      97     96
# 79   64      30      76     75
# 80   59      74      80     67
# 82   67      53      53     77
# 83   62      36      70     87
# ...

# %%
df1.loc[filter1 | filter2]
# Out:
#     Age  Height  Weight  speed
# 1     6      63      66     53
# 2    37      81      69     42
# 5    43      29      22     35
# 7    80      28      22     94
# 8    86      86       4     94
# ..  ...     ...     ...    ...
# 94   36      79      55     48
# 95   74      21      57     50
# 97   38      71      79     47
# 98   29      30      62      8
# 99   25      56     100     49
#
# [79 rows x 4 columns]
